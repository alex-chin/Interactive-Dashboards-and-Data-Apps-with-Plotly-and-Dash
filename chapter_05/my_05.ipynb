# %%
import pandas as pd

# %%
df = pd.read_csv('../data/PovStatsSeries.csv')

# %%
df.head()
# Out:
#       Series Code                         Topic  \
# 0  SI.DST.02ND.20  Poverty: Income distribution
# 1  SI.DST.03RD.20  Poverty: Income distribution
# 2  SI.DST.04TH.20  Poverty: Income distribution
# 3  SI.DST.05TH.20  Poverty: Income distribution
# 4  SI.DST.10TH.10  Poverty: Income distribution
#
#                      Indicator Name Short definition  \
# 0   Income share held by second 20%              NaN
# 1    Income share held by third 20%              NaN
# 2   Income share held by fourth 20%              NaN
# 3  Income share held by highest 20%              NaN
# 4  Income share held by highest 10%              NaN
#
#                                      Long definition Unit of measure  \
# 0  Percentage share of income or consumption is t...               %
# 1  Percentage share of income or consumption is t...               %
# 2  Percentage share of income or consumption is t...               %
# 3  Percentage share of income or consumption is t...               %
# ...

# %%
df['Indicator Name'].unique()
# Out:
# array(['Income share held by second 20%',
#        'Income share held by third 20%',
#        'Income share held by fourth 20%',
#        'Income share held by highest 20%',
#        'Income share held by highest 10%',
#        'Income share held by lowest 10%',
#        'Income share held by lowest 20%',
#        'Multidimensional poverty, Educational attainment (% of population deprived)',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#        'Poverty headcount ratio at $1.90 a day, age 0-14\xa0 (2011 PPP) (% of population age 0-14)',
#        'Poverty headcount ratio at $1.90 a day, age 15-64 (2011 PPP) (% of population age 15-64)',
#        'Poverty headcount ratio at $1.90 a day, without education (2011 PPP) (% of population age 16+ without education)',
#        'Poverty headcount ratio at $1.90 a day, with primary education (2011 PPP) (% of population age 16+ with primary education)',
# ...

# %%
gini = 'GINI index (World Bank estimate)'

# %%
df[df['Indicator Name'] == gini]['Long definition'].values[0]
# Out:
# 'Gini index measures the extent to which the distribution of income (or, in some cases, consumption expenditure) among individuals or households within an economy deviates from a perfectly equal distribution. A Lorenz curve plots the cumulative percentages of total income received against the cumulative number of recipients, starting with the poorest individual or household. The Gini index measures the area between the Lorenz curve and a hypothetical line of absolute equality, expressed as a percentage of the maximum area under the line. Thus a Gini index of 0 represents perfect equality, while an index of 100 implies perfect inequality.'

# %%
df[gini].min(), df[gini].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\project\att\Json_csv\.venv\Interactive-Dashboards-and-Data-Apps-with-Plotly-and-Dash\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GINI index (World Bank estimate)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
